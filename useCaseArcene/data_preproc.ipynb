# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer

# %%
df_train = pd.read_csv("ARCENE/arcene_train.data", header=None, delim_whitespace=True)
df_valid = pd.read_csv("ARCENE/arcene_valid.data", header=None, delim_whitespace=True)
df = pd.concat([df_train, df_valid], ignore_index=True)
# Out:
# /tmp/ipykernel_5973/375446157.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_train = pd.read_csv("ARCENE/arcene_train.data", header=None, delim_whitespace=True)
# /tmp/ipykernel_5973/375446157.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_valid = pd.read_csv("ARCENE/arcene_valid.data", header=None, delim_whitespace=True)

# %%
df = pd.DataFrame(KBinsDiscretizer(n_bins=4, encode='ordinal', strategy='quantile').fit_transform(df))
# Out:
# /home/usuario/miniconda3/envs/pytorch/lib/python3.13/site-packages/sklearn/preprocessing/_discretization.py:296: FutureWarning: The current default behavior, quantile_method='linear', will be changed to quantile_method='averaged_inverted_cdf' in scikit-learn version 1.9 to naturally support sample weight equivalence properties by default. Pass quantile_method='averaged_inverted_cdf' explicitly to silence this warning.
#   warnings.warn(
# /home/usuario/miniconda3/envs/pytorch/lib/python3.13/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /home/usuario/miniconda3/envs/pytorch/lib/python3.13/site-packages/sklearn/preprocessing/_discretization.py:397: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 2 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# ...

# %%
labels_train = pd.read_csv("ARCENE/arcene_train.labels", header=None, delim_whitespace=True)
labels_valid = pd.read_csv("arcene_valid.labels", header=None, delim_whitespace=True)
labels = pd.concat([labels_train, labels_valid], ignore_index=True)
# Out:
# /tmp/ipykernel_5973/2977531636.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   labels_train = pd.read_csv("ARCENE/arcene_train.labels", header=None, delim_whitespace=True)
# /tmp/ipykernel_5973/2977531636.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   labels_valid = pd.read_csv("arcene_valid.labels", header=None, delim_whitespace=True)

# %%
df_train.shape, df_valid.shape, df.isna().sum().sum(), labels.isna().sum().sum()
# Out:
# ((100, 10000), (100, 10000), 0, 0)

# %%
df["Target"] = labels
df.to_csv("arcene_preproc.csv", index=False)
